# %%
from PIL import Image
import glob

# %%
Norm=glob.glob('./Data_Norm/*')
AbNorm=glob.glob('./Data_AbNorm/*')

# %%
Norm
# Out:
# ['./Data_Norm\\20190809_155758.jpg',
#  './Data_Norm\\20190809_155801.jpg',
#  './Data_Norm\\20190809_155821.jpg',
#  './Data_Norm\\20190809_155828.jpg',
#  './Data_Norm\\20190809_155831.jpg',
#  './Data_Norm\\20190809_155833.jpg',
#  './Data_Norm\\20190809_155859.jpg',
#  './Data_Norm\\20190809_155922.jpg',
#  './Data_Norm\\20190809_155927.jpg',
#  './Data_Norm\\20190809_155931.jpg',
#  './Data_Norm\\20190809_160457.jpg',
#  './Data_Norm\\20190809_160723.jpg',
#  './Data_Norm\\20190809_160732.jpg',
#  './Data_Norm\\20190809_160856.jpg',
#  './Data_Norm\\20190809_160907.jpg',
#  './Data_Norm\\20190809_161035.jpg',
#  './Data_Norm\\20190809_161528.jpg',
#  './Data_Norm\\20190809_161533.jpg',
#  './Data_Norm\\20190809_164112.jpg',
#  './Data_Norm\\20190809_164116.jpg',
#  './Data_Norm\\20190809_164125.jpg',
#  './Data_Norm\\20190809_164132.jpg',
#  './Data_Norm\\20190809_164135.jpg',
#  './Data_Norm\\20190809_164144.jpg',
#  './Data_Norm\\20190809_164457.jpg',
# ...

# %%
Norm[100]
# Out:
# './Data_Norm\\rotated_by_15_Screen Shot 2018-06-08 at 5.15.21 PM.png'

# %%
Norm[100][-3:]
# Out:
# 'png'

# %%
for i in range(len(Norm)):
    if Norm[i][-3:]=='png':
        im = Image.open(Norm[i]).convert('RGB')
        im.save(f'{i}_Norm.jpg', 'jpeg')

# %%
for i in range(len(AbNorm)):
    if AbNorm[i][-3:]=='png':
        im = Image.open(AbNorm[i]).convert('RGB')
        im.save(f'{i}_AbNorm.jpg', 'jpeg')
